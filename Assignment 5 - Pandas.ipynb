# %% [markdown]
# # Assignment 5 Questions

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### Task 1:
#
# Read the dataset from the bellow link
#
# url = https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv'
data=pd.read_csv(url)
data.head()
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy

# %% [markdown]
# Questions

# %% [markdown]
# 1. Delete unnamed columns

# %%
data.info()
# since all data column are named,nothing will be deleted.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258000 entries, 0 to 257999
# Data columns (total 4 columns):
# year       258000 non-null int64
# name       258000 non-null object
# percent    258000 non-null float64
# sex        258000 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 7.9+ MB

# %% [markdown]
# 2. Show the distribution of male and female

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
plt.xticks(rotation = 60)
plt.title('Distribution of male and female over years')
plt.xlabel("Year")
plt.ylabel("count")
sns.countplot(data['year'],hue=data['sex'])

# %% [markdown]
# 3. Show the top 5 most preferred names

# %%
data.name.value_counts()[0:5]
# Out:
# Jessie       258
# Leslie       247
# Jean         244
# Guadalupe    244
# Lee          240
# Name: name, dtype: int64

# %% [markdown]
# 4. What is the median name occurence in the dataset

# %%
data.name.value_counts().median()
# Out:
# 19.0

# %% [markdown]
# 5. Distribution of male and female born count by states

# %%
# state not present
a=data.groupby(['year','sex'])
a.first()
# Out:
#               name   percent
# year sex
# 1880 boy      John  0.081541
#      girl     Mary  0.072381
# 1881 boy      John  0.080975
#      girl     Mary  0.069986
# 1882 boy      John  0.078314
#      girl     Mary  0.070431
# 1883 boy      John  0.079066
#      girl     Mary  0.066737
# 1884 boy      John  0.076476
#      girl     Mary  0.066990
# 1885 boy      John  0.075517
#      girl     Mary  0.064300
# 1886 boy      John  0.075820
#      girl     Mary  0.064334
# 1887 boy      John  0.074181
#      girl     Mary  0.063620
# 1888 boy      John  0.071186
#      girl     Mary  0.062041
# 1889 boy      John  0.071804
#      girl     Mary  0.061562
# 1890 boy      John  0.071034
#      girl     Mary  0.059892
# 1891 boy      John  0.070292
#      girl     Mary  0.059543
# 1892 boy      John  0.068759
#      girl     Mary  0.058570
# 1893 boy      John  0.066495
#      girl     Mary  0.056757
# 1894 boy      John  0.065961
#      girl     Mary  0.055730
# ...

# %% [markdown]
# #### Task 2:
#
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
#
#     Task:
#     1. fitting it to the periodic function
#     2. plot the fit
#
#     Data
#     Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#     Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

temp_max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
months = np.arange(12)

# plt.plot(months, temp_max, 'go')
# plt.plot(months, temp_min, 'co')
# plt.xlabel('Month')
# plt.ylabel('Min and max temperature')
# plt.title('Tempreature variance')
# plt.show()
sns.scatterplot(months, temp_max,)
sns.scatterplot(months, temp_min)
plt.xlabel('Month')
plt.ylabel('Min and max temperature')
plt.title('Tempreature variance')
# Out:
# Text(0.5, 1.0, 'Tempreature variance')
